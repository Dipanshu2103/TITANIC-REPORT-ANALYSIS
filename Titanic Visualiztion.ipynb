# %%
# import the all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset
titanic=pd.read_csv('titanic.csv')

# %%
# making the copy of the original dataset
df= titanic.copy()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# set PassengerId as an index
df.set_index('PassengerId',inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ## Create a pie chart which should show the distribution of male and female

# %%
a= df['Sex'].value_counts()

# %%
plt.pie(a, labels=a.index, autopct="%1.1f%%",colors=['skyblue','pink'], startangle=90, explode=[0,0.1])
plt.title("Sex Proportion")
# Out:
# Text(0.5, 1.0, 'Sex Proportion')

# %%
plt.pie(a,labels = [f"male: {a['male']}", f"female: {a['female']}"],
       labeldistance=1.12,pctdistance=1.09999,colors=['skyblue','pink'], startangle=90)
plt.title('passenger count by sex')
plt.show()

# %%
def number(pct): 
    return f"{int(round(pct*sum(a)/100))}"

plt.pie(a, labels=a.index, colors=['skyblue','pink'], startangle=90, autopct=number)
plt.title("Sex Proportion")
plt.show()

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ## Distribution of Fare and Age on the bases of Gender

# %%
plt.scatter(df[df['Sex']=='male']['Age'],df[df['Sex']=='male']['Fare'],label='male',c='blue')
plt.scatter(df[df['Sex']=='female']['Age'],df[df['Sex']=='female']['Fare'],label='female',c='pink')
plt.legend()
plt.title("Fare X Age")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# ## Distribution of Fare on the basis of Passengers

# %%
plt.hist(df['Fare'],bins=30,color='skyblue',edgecolor='black')
plt.xlabel("Fare")
plt.ylabel("Number of Passengers")
plt.title("Histogram of Fare Paid")
plt.show()

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ## What is the overall survival rate?

# %%
plt.pie(df['Survived'].value_counts(),
        labels=['Death','Survived'],
        autopct="%1.1f%%",
        colors=["Red","Green"],
        wedgeprops={'width': 0.4},
        pctdistance=0.78,
        startangle=90)
plt.title("Overall Survival Rate")
plt.show()

# %%
## Creating a pie chart
plt.pie(df['Survived'].value_counts(),
        labels=['Death','Survived'],
        autopct="%1.1f%%",
        colors=["Red","Green"],
        startangle=90)
plt.title("Overall Survival Rate")
plt.show()

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ## What is the distribution of ages?

# %%
count, bins,_ =plt.hist(df['Age'],bins=8,rwidth=0.8)
labels = [f'{int(bins[i])}-{int(bins[i+1])}' for i in range(len(bins)-1)]
plt.xticks([(bins[i] + bins[i+1])/2 for i in range(len(bins)-1)],labels)
plt.title('Age Distribution')
plt.xlabel('Age Groups')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### with seaborn

# %%
age_data = df['Age'].dropna()
counts, bins = np.histogram(age_data, bins=8)
sns.histplot(age_data, bins=bins, shrink=0.8)
labels = [f'{int(bins[i])}-{int(bins[i+1])}' for i in range(len(bins) - 1)]
plt.xticks(ticks=[(bins[i] + bins[i+1]) / 2 for i in range(len(bins) - 1)],
           labels=labels)
plt.xlabel('Age Groups')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ## Which passenger class (Pclass) had the most passengers?

# %%
plt.bar(df['Pclass'].value_counts().index,df['Pclass'].value_counts())
plt.xlabel('passenger class')
plt.ylabel('Number of passengers')
plt.title('Passenger Class Distribution')
plt.xticks([1,2,3],
           labels=["upper" if x ==1 else "middle" if x==2 else "lower" for x in range(1,4)])
plt.show()

# %% [markdown]
# ## with seaborn

# %%
sns.countplot(x='Pclass', data=df)
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.title('Passenger Class Distribution')
plt.xticks([0, 1, 2], ['upper', 'middle', 'lower'])
plt.show()

# %% [markdown]
# ## Did gender affect the survival rate?

# %%
a = df[df['Sex']=='male']['Sex'].value_counts()
b = df[(df['Sex'] == 'male') & (df['Survived'] == 1)]['Sex'].value_counts()
c = round((b/a)*100,2)
c
# Out:
# Sex
# male    18.89
# Name: count, dtype: float64

# %%
d = df[df['Sex']=='female']['Sex'].value_counts()
e = df[(df['Sex'] == 'female') & (df['Survived'] == 1)]['Sex'].value_counts()
f = round((e/d)*100,2)
f
# Out:
# Sex
# female    74.2
# Name: count, dtype: float64

# %%
survival_rates = {
    'Male': float(c['male']),
    'Female': float(f['female'])}
survival_rates
# Out:
# {'Male': 18.89, 'Female': 74.2}

# %%
plt.bar(survival_rates.keys(), survival_rates.values(), color=['skyblue', 'pink'])
plt.ylabel("Survival Percentage")
plt.title("Survival Rate by Gender")
plt.show()

# %%
plt.pie(survival_rates.values(),
        labels=survival_rates.keys(),
        autopct='%1.1f%%',
        colors=['skyblue', 'pink'],
        startangle=90)

plt.title("Survival Rate by Gender")
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Distribution of passengers according to embarked from each port.

# %%
sns.countplot(data =df, x='Embarked')
plt.title('Passengers Breakdown of Embarked Location')
plt.ylabel("Total Number of Passengers")
plt.grid()
plt.show()
# S → Southampton (England)
# C → Cherbourg (France)
# Q → Queenstown (Ireland)

# %% [markdown]
# ## Which class of passengers mostly embarked from each port?

# %%
sns.countplot(data =df, x='Embarked', hue='Pclass',palette='deep')
plt.title('Class-wise Breakdown of Embarked Passengers')
plt.ylabel("Total Number of Passengers")
plt.grid()
plt.show()
# S → Southampton (England)
# C → Cherbourg (France)
# Q → Queenstown (Ireland)

# %% [markdown]
# ## Distribution of gender across passenger classes.

# %%
sns.countplot(data= df, x='Pclass', hue='Sex')
plt.ylabel("Total Number of Passengers")
plt.title("Distribution of gender across passenger classes")
plt.grid()
plt.show()

# %% [markdown]
# ## Distribution of Passengers on the basis of SibSp

# %%
sns.countplot(data=df,x='SibSp')
plt.title("Passenger Distribution Based on SibSp")
plt.ylabel("Total Number of Passengers")
plt.grid()
plt.show()

# %% [markdown]
# ## What is the survival and death distribution by embarkation port?

# %%
sns.countplot(data=df, hue='Survived', x='Embarked')
plt.title("Survival Status Across Embarked Locations")
plt.ylabel("Total Number of Passengers")
plt.legend(title='Survival Status', labels=['Died', 'Survived'])
plt.grid()
plt.show()
# S → Southampton (England)
# C → Cherbourg (France)
# Q → Queenstown (Ireland)

# %% [markdown]
# ## How does fare vary by embarkation point?

# %%
sns.barplot(data=df, x='Embarked', y="Fare", errorbar=None)
plt.title("Average Fare Across Embarked Locations")
plt.grid()
plt.show()
# S → Southampton (England)
# C → Cherbourg (France)
# Q → Queenstown (Ireland)

# %% [markdown]
# ## What are the average ages of passengers from different embarkation ports?

# %%
sns.barplot(data=df, x='Embarked',y='Age',errorbar=None)
plt.title("Averge Age Distribution Across Embarked Locations")
plt.grid()
plt.show()
# S → Southampton (England)
# C → Cherbourg (France)
# Q → Queenstown (Ireland)
